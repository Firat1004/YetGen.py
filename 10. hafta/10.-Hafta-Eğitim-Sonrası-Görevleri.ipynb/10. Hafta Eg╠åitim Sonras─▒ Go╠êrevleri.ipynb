# %% [markdown]
# # Problem 1

# %%
# 1 - numpy kütüphanesini import edin
import numpy as np

# 2 - 5 elemanlı bir numpy array oluşturun
dizi = np.array([42, 7, 19, 3, 25])
print("Orijinal dizi:", dizi)

# 3 - Oluşturduğunuz arrayi küçükten büyüğe sıralayın
sirali_dizi = np.sort(dizi)
print("Sıralanmış dizi:", sirali_dizi)

# %% [markdown]
# # Problem 2

# %%
import numpy as np

dizi1 = np.array([10, 15, 30, 45, 60])
dizi2 = np.arange(5, 16)
dizi3 = np.arange(50, 101, 5)
dizi4 = np.zeros(10)
dizi5 = np.ones(10)
dizi6 = np.linspace(0, 100, 5)
dizi7 = np.random.randint(10, 30, 5)
dizi8 = np.random.uniform(-1, 1, 10)
matris = np.random.randint(10, 50, (3, 5))
satir_toplamlari = matris.sum(axis=1)
sutun_toplamlari = matris.sum(axis=0)
en_buyuk = matris.max()
en_kucuk = matris.min()
ortalama = matris.mean()
en_buyuk_indeks = np.unravel_index(matris.argmax(), matris.shape)
dizi9 = np.arange(10, 21)
ilk_3 = dizi9[:3]
ters = dizi9[::-1]
ilk_satir = matris[0]
eleman = matris[1, 2]
ilk_elemanlar = matris[:, 0]
kareler = matris ** 2
matris2 = np.random.randint(-50, 51, (3, 5))
pozitif_ciftler = matris2[(matris2 > 0) & (matris2 % 2 == 0)]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       3 dizi1 = np.array([10, 15, 30, 45, 60])
#       4 dizi2 = np.arange(5, 16)
#
# ModuleNotFoundError: No module named 'numpy'
